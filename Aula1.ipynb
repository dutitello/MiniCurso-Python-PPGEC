# %% [markdown]
# Universidade Federal do Rio Grande do Sul (UFRGS)
# Programa de Pós-Graduação em Engenharia Civil (PPGEC)
#
#
# # Python aplicado à análise de estruturas
# ## Aula 1: Introdução
#
# [1. Por que Python?](#section_1)
#
# [2. Instalação do Anaconda](#section_2)
#
# [3. Spyder: Ambiente semelhante ao MATLAB](#section_3)
#
# [4. Jupyter: Caderno interativo](#section_4)
#
# [ 4.1. Células de código Python](#section_41)
#
# [ 4.2. Células Markdown](#section_42)
#
# [ 4.3. Google Colaboratory](#section_43)
#
# ---
#
# _Eng. MSc Eduarto Pagnussat Titello_
#
# _Eng. Daniel Barbosa M. Matos_

# %% [markdown]
# # Por que Python?<a name="section_1"></a>
#
# Python é uma linguagem de código aberto, de fácil interpretação que exige menos o programador e mais da máquina, sendo, portanto, uma linguagem facilmente legível, que não prioriza a velocidade de execução. Hoje, a linguagem é amplamente utilizada devido ao vasto número de bibliotecas gratuitas disponíveis, que possibilitam uma infinidade realizações.

# %% [markdown]
# # Instalação do Anaconda<a name="section_2"></a>
#
# É uma distribuição gratuita da linguagem Python que possui diversas ferramentas, bibliotecas e ambientes.Sua instalação é aconselhável por já possuir as principais bibliotecas necessárias e um gerenciador de pacotes. Para baixar clique [aqui](https://www.anaconda.com/products/individual) e escolha a versão adequada para o seu sistema operacional.
#
# ![ANACONDA.PNG](Resources/ANACONDA.PNG)
#
# Ao abrir o instalador, basta clicar avançar em todas as janelas.
#
# Após instalado, o seguinte ambiente poderá ser visualizado:
#
# ![Anacondainterface.png](Resources/Anacondainterface2.png)
#
# Dos ambientes que podem ser visualizados na figura acima, os que serão abordados neste minicurso são Spyder e Jupyter notebook.

# %% [markdown]
# #  Spyder: Ambiente semelhante ao MATLAB<a name="section_3"></a>
# O ambiente Spyder é bastante semelhante ao MATLAB, tendo, assim como este, um editor de código, um explorador de variáveis, figuras e arquivos e um console, como pode ser visto na figura abaixo.Este ambiente também possibilita a depuração do código, sendo possível o rastreamento de erros.
# ![image.png](attachment:image.png)

# %% [markdown]
# # Jupyter notebook: Caderno interativo<a name="section_4"></a>
#   O Jupyter notebook consiste numa aplicação que permite criar e compartilhar documentos com código ativo. Este permite que o código seja construído por células, não havendo a necessidade rodar todo o programa a cada alteração feita no código. Neste ambiente são encontradas dois tipos principais de células, sendo elas Python e Markdown. A célula Python é utilizada para o processamento do código, enquanto a markdown é utilizada com o intuito de documentar o código. O ambiente Jupyter pode ser visualizado abaixo.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Células de código Python<a name="section_41"></a>
#
# Estas células contém parte do código podendo ser processadas individualmente, obtendo resultados parciais durante o processo, que ficam gravados no arquivo. É importante verificar no canto superior esquerdo a sequência em que as células estão sendo processadas. Para processar uma célula, basta clicar no botão ```Run``` ou apertar as teclas ```shift```+```enter```.

# %% [markdown]
# ## Células de Markdown<a name="section_42"></a>
# São células de documentação, onde podem ser inseridas equações em LateX, links, figuras e tabelas. Clique [aqui](https://docs.pipz.com/central-de-ajuda/learning-center/guia-basico-de-markdown#open) para um guia rápido de Markdown. Para entender como funcionam as equações em LateX, clique [aqui](Resources/latex_symbols.pdf).
#
# \begin{bmatrix}
# 0\\
# 0\\
# 0\\
# \end{bmatrix}

# %% [markdown]
# ## Google Colab<a name="section_43"></a>
# Existem implementações do Jupyter que rodam na nuvem e podem ser acessadas sem qualquer instalação. Uma dessas é o Google Colaboratoy, que pode ser acessado [aqui](https://colab.research.google.com/) com uma conta Google, onde os notebooks são salvos no Google Drive da conta. A interface do Google Colaboratory pode ser visualizada a seguir.
# ![Google Colaboratory](./Resources/GoogleColab.png)

# %%
print("oi")

# %%
Isso é uma equação $ y = ax^2$
# Out:
#   File "<ipython-input-1-bedea102a476>", line 1
#     Isso é uma equação $ y = ax^2$
#          ^
# SyntaxError: invalid syntax

# %%
print(a)
